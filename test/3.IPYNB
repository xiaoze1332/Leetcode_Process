# %%
# 剪绳子进阶版
# 1. 一根绳子，剪成m段，每段长度为n1,n2,n3...nm，求乘积最大值，要求每段长度为整数

# %%
def cutRope(self , number: int) -> int:
    # 1. 递归
    # 2. 动态规划
    # 3. 贪心算法
    # 4. 数学推导
    # 5. 二分法
    # 6. 二进制

# %%
def cutRope(number: int) -> int:
    # DP
    dp = [0] * (number + 1)
    dp[1] = 1
    for i in range(2, number + 1):
        for j in range(1, i):
            dp[i] = max(dp[i], j * (i - j), j * dp[i - j])
    return dp[number]

# %%
def cutRope(number: int) -> int:
    res = 0
    for i in range(2, number + 1):
        res = max(res, self.cutRopeCore(number, i))
    return res

def cutRopeCore(number: int, m: int) -> int:
    if m == 1:
        return number
    if number == 1:
        return 1
    res = 0
    for i in range(1, number // m + 1):
        res = max(res, i * self.cutRopeCore(number - i, m - 1))
    return res

# %%
def cutRope(number: int) -> int:
    # 时间复杂度 O(logN)，最好算法
    if number == 2:
        return 1
    if number == 3:
        return 2
    if number == 4:
        return 4
    res = 1
    while number > 4:
        res *= 3
        number -= 3
    return res * number

def cutRope(number: int) -> int:
    # 二分法
    if number == 2:
        return 1
    if number == 3:
        return 2
    if number == 4:
        return 4
    res = 1
    while number > 4:
        res *= 3
        number -= 3
    return res * number

def cutRope(number: int) -> int:
    # 二进制
    if number == 2:
        return 1
    if number == 3:
        return 2
    if number == 4:
        return 4
    res = 1
    while number > 4:
        res *= 3
        number -= 3
    return res * number

# Path: test\4.IPYNB
# 1. 一根绳子，剪成m段，每段长度为n1,n2,n3...nm，求乘积最大值，要求每段长度为整数
# 2. 一根绳子，剪成m段，每段长度为n1,n2,n3...nm，求乘积最大值，要求每段长度为整数，且每段长度都不相同

def cutRope(self , number: int) -> int:
    # 1. 递归
    # 2. 动态规划
    # 3. 贪心算法
    # 4. 数学推导
    # 5. 二分法
    # 6. 二进制

def cutRope(number: int) -> int:
    # DP
    dp = [0] * (number + 1)
    dp[1] = 1
    for i in range(2, number + 1):
        for j in range(1, i):
            dp[i] = max(dp[i], j * (i - j), j * dp[i - j])
    return dp[number]

def cutRope(number: int) -> int:
    res = 0
    for i in range(2, number + 1):
        res = max(res, self.cutRopeCore(number, i))
    return res

def cutRopeCore(number: int, m: int) -> int:

    if m == 1:
        return number
    if number == 1:
        return 1
    res = 0
    for i in range(1, number // m + 1):
        res = max(res, i * self.cutRopeCore(number - i, m - 1))
    return res

def cutRope(number: int) -> int:

    # 时间复杂度 O(logN)，最好算法
    if number == 2:
        return 1
    if number == 3:
        return 2
    if number == 4:
        return 4
    res = 1
    while number > 4:
        res *= 3
        number -= 3
    return res * number

def cutRope(number: int) -> int:
    # 二分法
    if number == 2:
        return 1
    if number == 3:
        return 2
    if number == 4:
        return 4
    res = 1
    while number > 4:
        res *= 3
        number -= 3
    return res * number

def cutRope(number: int) -> int:
    # 二进制
    if number == 2:
        return 1
    if number == 3:
        return 2
    if number == 4:
        return 4
    res = 1
    while number > 4:
        res *= 3
        number -= 3
    return res * number

# Path: test\5.IPYNB

# %%
number = 5

# %%
print(cutRope(number))
# Out:
# 6
