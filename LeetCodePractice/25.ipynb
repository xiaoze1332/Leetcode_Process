# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseKGroup(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:
        # use stack to solve this problem
        # 1. push k nodes into stack
        # 2. pop k nodes from stack and connect them
        # 3. repeat 1 and 2 until the end of the list
        # 4. connect the last k nodes
        # 5. return the head of the reversed list

        # edge case
        if head is None or k == 1:
            return head
        else:
            stack = []
            dummy = ListNode(0)
            dummy.next = head

            # 1. push k nodes into stack
            # 2. pop k nodes from stack and connect them
            # 3. repeat 1 and 2 until the end of the list
            # 4. connect the last k nodes
            # 5. return the head of the reversed list
            prev = dummy
            while head:
                for i in range(k):
                    if head:
                        stack.append(head)
                        head = head.next
                    else:
                        prev.next = stack[0]
                        return dummy.next
                while stack:
                    prev.next = stack.pop()
                    prev = prev.next
                prev.next = head

            return dummy.next

# %%
class Solution:
    def reverseKGroup(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:

        if head is None or k == 1:
            return head
        else:
            stack = []
            dummy = ListNode(0)
            dummy.next = head

            prev = dummy

            while head:
                for i in range(k):
                    if head:
                        stack.append(head)
                        head = head.next
                    else:
                        prev.next = stack[0]
                        return dummy.next
                while stack:
                    prev.next = stack.pop()
                    prev = prev.next
                prev.next = head

            return dummy.next
